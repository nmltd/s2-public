// %%
/**
 * Demonstrate how to plot histograms with means.
 *
 * @author Haksun Li
 */

%use s2, lets-plot

// construct a standard normal random number generator
val rng = NormalRNG(
    0.0, // mean
    1.0) // standard deviation
rng.seed(1234567890L)

// the number of data to generate
val N = 200
// generate the random data to plot
val data = mapOf<String, Any>(
    "cond" to List(N) { "A" } + List(N) { "B" },
    "rating" to List(N) { rng.nextDouble() } + List(N) { rng.nextDouble() * 1.5 + 1.5 },
)

// find the mean of each group
val means = (data["cond"] as List<String> zip data["rating"] as List<Double>)
        .groupBy(keySelector = { it.first }, valueTransform = { it.second })
        .mapValues { it.value.average() }
val cdat = mapOf(
    "cond" to means.keys,
    "rating" to means.values
)
println(cdat)

// Overlaid histograms with means
val plot = ggplot(data) {x="rating"; color="cond"} + // supply data; set legends
    ggsize(500, 250) + // plot size
    geom_histogram(alpha=.3, position=Pos.identity, size=0.0, bins=10) {fill="cond"} + // draw histograms
    geom_vline(data=cdat, linetype="dashed", size=1.0) {xintercept="rating"; color="cond"} // draw the vertical lines of means
plot
// Out:
//    <div id="H9rChW"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.5.2.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("H9rChW").appendChild(div);
//            };
//            var e = document.getElementById("H9rChW");
//            e.appendChild(script);
//        })();
//    </script>
// {cond=[A, B], rating=[-3.3812632581654454E-4, 1.3530503384104802]}
//    <div id="6cXk9f"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// 'mapping':{
// 'color':"cond",
// 'x':"rating"
// },
// 'data':{
// },
// 'ggsize':{
// 'width':500,
// 'height':250
// },
// 'kind':"plot",
// 'scales':[],
// 'layers':[{
// 'stat':"bin",
// 'mapping':{
// 'fill':"cond"
// },
// 'bins':10,
// 'size':0.0,
// 'data':{
// '..count..':[0.0,0.0,36.0,61.0,74.0,27.0,2.0,0.0,0.0,0.0,2.0,3.0,9.0,23.0,46.0,46.0,39.0,22.0,7.0,3.0],
// 'rating':[-3.5048755562654366,-2.5139089483240213,-1.5229423403826063,-0.5319757324411913,0.4589908755002239,1.449957483441639,2.440924091383054,3.4318906993244696,4.422857307265884,5.4138239152073,-3.5048755562654366,-2.5139089483240213,-1.5229423403826063,-0.5319757324411913,0.4589908755002239,1.449957483441639,2.440924091383054,3.4318906993244696,4.422857307265884,5.4138239152073],
// 'cond':["A","A","A","A","A","A","A","A","A","A","B","B","B","B","B","B","B","B","B","B"]
// },
// 'alpha':0.3,
// 'position':"identity",
// 'geom':"histogram"
// },{
// 'stat':"identity",
// 'mapping':{
// 'color':"cond",
// 'xintercept':"rating"
// },
// 'data':{
// 'rating':[-3.3812632581654454E-4,1.3530503384104802],
// 'cond':["A","B"]
// },
// 'size':1.0,
// 'linetype':"dashed",
// 'position':"identity",
// 'geom':"vline"
// }]
// };
//            var plotContainer = document.getElementById("6cXk9f");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
